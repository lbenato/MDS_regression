# %%
from source import Dataset
import numpy as np
import awkward as ak
import glob
import time
import pandas as pd

# %%
branches_to_read = [
"weight",
"evtNum",
"cscRechitCluster_match_gLLP",
"cscRechitCluster_match_gLLP_minDeltaR",
"cscRechitCluster_match_gLLP_index",
"cscRechitCluster_match_gLLP_eta",
"cscRechitCluster_match_gLLP_phi",
"cscRechitCluster_match_gLLP_decay_r",
"cscRechitCluster_match_gLLP_decay_z",
"cscRechitCluster_match_gLLP_csc",
"cscRechitCluster_match_gLLP_dt",
"cscRechitCluster_match_gLLP_e",
"cscRechitClusterX",
"cscRechitClusterY",
"cscRechitClusterZ",
"cscRechitClusterTimeWeighted",
"cscRechitClusterTimeSpreadWeightedAll",
"cscRechitClusterTime",
"cscRechitClusterTimeSpread",
"cscRechitClusternXY",
"cscRechitClusternZ",
"cscRechitClusterXSpread",
"cscRechitClusterYSpread",
"cscRechitClusterZSpread",
"cscRechitClusterXYSpread",
"cscRechitClusterRSpread",
"cscRechitClusterEtaPhiSpread",
"cscRechitClusterEtaSpread",
"cscRechitClusterPhiSpread",
"cscRechitClusterDeltaRSpread",
"cscRechitClusterMajorAxis",
"cscRechitClusterMinorAxis",
"cscRechitClusterSkewX",
"cscRechitClusterSkewY",
"cscRechitClusterSkewZ",
"cscRechitClusterKurtX",
"cscRechitClusterKurtY",
"cscRechitClusterKurtZ",
"cscRechitClusterPhi",
"cscRechitClusterEta",
"cscRechitClusterJetVetoPt",
"cscRechitClusterJetVetoLooseId",
"cscRechitClusterJetVetoTightId",
"cscRechitClusterJetVetoE",
"cscRechitClusterMuonVetoPt",
"cscRechitClusterMuonVetoE",
"cscRechitClusterMuonVetoLooseId",
"cscRechitClusterMuonVetoGlobal",
"cscRechitCluster_match_dtSeg_0p4",
"cscRechitCluster_match_MB1Seg_0p4",
"cscRechitCluster_match_RE12_0p4",
"cscRechitCluster_match_RB1_0p4",
"cscRechitClusterSize",
"cscRechitClusterNStation10",
"cscRechitClusterAvgStation10",
"cscRechitClusterMaxStation",
"cscRechitClusterMaxStationRatio",
"cscRechitClusterNChamber",
"cscRechitClusterMaxChamber",
"cscRechitClusterMaxChamberRatio",
"cscRechitClusterNRechitChamberPlus11",
"cscRechitClusterNRechitChamberPlus12",
"cscRechitClusterNRechitChamberPlus13",
"cscRechitClusterNRechitChamberPlus21",
"cscRechitClusterNRechitChamberPlus22",
"cscRechitClusterNRechitChamberPlus31",
"cscRechitClusterNRechitChamberPlus32",
"cscRechitClusterNRechitChamberPlus41",
"cscRechitClusterNRechitChamberPlus42",
"cscRechitClusterNRechitChamberMinus11",
"cscRechitClusterNRechitChamberMinus12",
"cscRechitClusterNRechitChamberMinus13",
"cscRechitClusterNRechitChamberMinus21",
"cscRechitClusterNRechitChamberMinus22",
"cscRechitClusterNRechitChamberMinus31",
"cscRechitClusterNRechitChamberMinus32",
"cscRechitClusterNRechitChamberMinus41",
"cscRechitClusterNRechitChamberMinus42",
"cscRechitClusterMet_dPhi",
]
print(branches_to_read)
# Out:
# ['weight', 'evtNum', 'cscRechitCluster_match_gLLP', 'cscRechitCluster_match_gLLP_minDeltaR', 'cscRechitCluster_match_gLLP_index', 'cscRechitCluster_match_gLLP_eta', 'cscRechitCluster_match_gLLP_phi', 'cscRechitCluster_match_gLLP_decay_r', 'cscRechitCluster_match_gLLP_decay_z', 'cscRechitCluster_match_gLLP_csc', 'cscRechitCluster_match_gLLP_dt', 'cscRechitCluster_match_gLLP_e', 'cscRechitClusterX', 'cscRechitClusterY', 'cscRechitClusterZ', 'cscRechitClusterTimeWeighted', 'cscRechitClusterTimeSpreadWeightedAll', 'cscRechitClusterTime', 'cscRechitClusterTimeSpread', 'cscRechitClusternXY', 'cscRechitClusternZ', 'cscRechitClusterXSpread', 'cscRechitClusterYSpread', 'cscRechitClusterZSpread', 'cscRechitClusterXYSpread', 'cscRechitClusterRSpread', 'cscRechitClusterEtaPhiSpread', 'cscRechitClusterEtaSpread', 'cscRechitClusterPhiSpread', 'cscRechitClusterDeltaRSpread', 'cscRechitClusterMajorAxis', 'cscRechitClusterMinorAxis', 'cscRechitClusterSkewX', 'cscRechitClusterSkewY', 'cscRechitClusterSkewZ', 'cscRechitClusterKurtX', 'cscRechitClusterKurtY', 'cscRechitClusterKurtZ', 'cscRechitClusterPhi', 'cscRechitClusterEta', 'cscRechitClusterJetVetoPt', 'cscRechitClusterJetVetoLooseId', 'cscRechitClusterJetVetoTightId', 'cscRechitClusterJetVetoE', 'cscRechitClusterMuonVetoPt', 'cscRechitClusterMuonVetoE', 'cscRechitClusterMuonVetoLooseId', 'cscRechitClusterMuonVetoGlobal', 'cscRechitCluster_match_dtSeg_0p4', 'cscRechitCluster_match_MB1Seg_0p4', 'cscRechitCluster_match_RE12_0p4', 'cscRechitCluster_match_RB1_0p4', 'cscRechitClusterSize', 'cscRechitClusterNStation10', 'cscRechitClusterAvgStation10', 'cscRechitClusterMaxStation', 'cscRechitClusterMaxStationRatio', 'cscRechitClusterNChamber', 'cscRechitClusterMaxChamber', 'cscRechitClusterMaxChamberRatio', 'cscRechitClusterNRechitChamberPlus11', 'cscRechitClusterNRechitChamberPlus12', 'cscRechitClusterNRechitChamberPlus13', 'cscRechitClusterNRechitChamberPlus21', 'cscRechitClusterNRechitChamberPlus22', 'cscRechitClusterNRechitChamberPlus31', 'cscRechitClusterNRechitChamberPlus32', 'cscRechitClusterNRechitChamberPlus41', 'cscRechitClusterNRechitChamberPlus42', 'cscRechitClusterNRechitChamberMinus11', 'cscRechitClusterNRechitChamberMinus12', 'cscRechitClusterNRechitChamberMinus13', 'cscRechitClusterNRechitChamberMinus21', 'cscRechitClusterNRechitChamberMinus22', 'cscRechitClusterNRechitChamberMinus31', 'cscRechitClusterNRechitChamberMinus32', 'cscRechitClusterNRechitChamberMinus41', 'cscRechitClusterNRechitChamberMinus42', 'cscRechitClusterMet_dPhi']

# %% [markdown]
# ## Signal

# %%
#signal 
wildcard = "/nfs/dust/cms/group/cms-llp/muon_system_run3/V1p19/Data2022/v6_Pedro_newDNN/mc.root"

dataset_signal = Dataset.Dataset("signal")
pre_ak_array = dataset_signal.create_ak_array_from_tree(wildcard, "MuonSystem", branches_to_read, verbosity=1)


print(dataset_signal.ak_array_raw)
print(dataset_signal.ak_array_unrolled)
print(dataset_signal.np_array_structured)
print(dataset_signal.np_array_unstructured)

#Filter out events without gen matched CSC clusters
ak_array = pre_ak_array[ ak.any(pre_ak_array["cscRechitCluster_match_gLLP"],axis=1)>=1 ]
#ak_array
#print(ak_array)
# Out:
# converting the following root files and trees
# /nfs/dust/cms/group/cms-llp/muon_system_run3/V1p19/Data2022/v6_Pedro_newDNN/mc.root:MuonSystem
# start loading
# converted trees to awkward array
# found 1851400 events
# None
# None
# None
# None

# %%
# check length of array (number of events)
print("number of events:", len(ak_array))

#print(ak_array[2].fields)

#check values for keys
#for k in ak_array[2].fields:
#    print(k, ak_array[2][k])
    
#print(ak_array[2])
#print(type(dataset_signal))

#print(dataset_signal.vectorize_and_pad_raw_array_cluster(ak_array,"csc",verbosity=1))
dataset_signal.ak_array_raw = ak_array
# Out:
# number of events: 327740

# %%
# vectorize array so that each cluster in Event is a column
vectorized_array = dataset_signal.vectorize_and_pad_raw_array_cluster(ak_array, "csc", verbosity=1)
unrolled_array = dataset_signal.unroll_raw_array_cluster(ak_array,verbosity=1)

#check lenght of array
print("length of the vectorized array:", len(vectorized_array))
print("length of the unrolled array:", len(unrolled_array))
#print(vectorized_array[0:5])
#print(unrolled_array[0:10])

# check entries
cols = []
for k in vectorized_array[1].fields:
    #print(k, vectorized_array[1][k])
    cols.append(k)
# Out:
# Final array contains 327740 entries
# stored the final array also as class variable ak_array_unrolled
# Turning event array into cluster array
# Processing event n.  1000
# Processing event n.  2000
# Processing event n.  3000
# Processing event n.  4000
# Processing event n.  5000
# Processing event n.  6000
# Processing event n.  7000
# Processing event n.  8000
# Processing event n.  9000
# Processing event n.  10000
# Processing event n.  11000
# Processing event n.  12000
# Processing event n.  13000
# Processing event n.  14000
# Processing event n.  15000
# Processing event n.  16000
# Processing event n.  17000
# Processing event n.  18000
# Processing event n.  19000
# Processing event n.  20000
# Processing event n.  21000
# Processing event n.  22000
# Processing event n.  23000
# Processing event n.  24000
# Processing event n.  25000
# Processing event n.  26000
# Processing event n.  27000
# Processing event n.  28000
# Processing event n.  29000
# Processing event n.  30000
# Processing event n.  31000
# Processing event n.  32000
# Processing event n.  33000
# Processing event n.  34000
# Processing event n.  35000
# Processing event n.  36000
# Processing event n.  37000
# Processing event n.  38000
# Processing event n.  39000
# Processing event n.  40000
# Processing event n.  41000
# Processing event n.  42000
# Processing event n.  43000
# Processing event n.  44000
# Processing event n.  45000
# Processing event n.  46000
# Processing event n.  47000
# Processing event n.  48000
# Processing event n.  49000
# Processing event n.  50000
# Processing event n.  51000
# Processing event n.  52000
# Processing event n.  53000
# Processing event n.  54000
# Processing event n.  55000
# Processing event n.  56000
# Processing event n.  57000
# Processing event n.  58000
# Processing event n.  59000
# Processing event n.  60000
# Processing event n.  61000
# Processing event n.  62000
# Processing event n.  63000
# Processing event n.  64000
# Processing event n.  65000
# Processing event n.  66000
# Processing event n.  67000
# Processing event n.  68000
# Processing event n.  69000
# Processing event n.  70000
# Processing event n.  71000
# Processing event n.  72000
# Processing event n.  73000
# Processing event n.  74000
# Processing event n.  75000
# Processing event n.  76000
# Processing event n.  77000
# Processing event n.  78000
# Processing event n.  79000
# Processing event n.  80000
# Processing event n.  81000
# Processing event n.  82000
# Processing event n.  83000
# Processing event n.  84000
# Processing event n.  85000
# Processing event n.  86000
# Processing event n.  87000
# Processing event n.  88000
# Processing event n.  89000
# Processing event n.  90000
# Processing event n.  91000
# Processing event n.  92000
# Processing event n.  93000
# Processing event n.  94000
# Processing event n.  95000
# Processing event n.  96000
# Processing event n.  97000
# Processing event n.  98000
# Processing event n.  99000
# Processing event n.  100000
# Processing event n.  101000
# Processing event n.  102000
# Processing event n.  103000
# Processing event n.  104000
# Processing event n.  105000
# Processing event n.  106000
# Processing event n.  107000
# Processing event n.  108000
# Processing event n.  109000
# Processing event n.  110000
# Processing event n.  111000
# Processing event n.  112000
# Processing event n.  113000
# Processing event n.  114000
# Processing event n.  115000
# Processing event n.  116000
# Processing event n.  117000
# Processing event n.  118000
# Processing event n.  119000
# Processing event n.  120000
# Processing event n.  121000
# Processing event n.  122000
# Processing event n.  123000
# Processing event n.  124000
# Processing event n.  125000
# Processing event n.  126000
# Processing event n.  127000
# Processing event n.  128000
# Processing event n.  129000
# Processing event n.  130000
# Processing event n.  131000
# Processing event n.  132000
# Processing event n.  133000
# Processing event n.  134000
# Processing event n.  135000
# Processing event n.  136000
# Processing event n.  137000
# Processing event n.  138000
# Processing event n.  139000
# Processing event n.  140000
# Processing event n.  141000
# Processing event n.  142000
# Processing event n.  143000
# Processing event n.  144000
# Processing event n.  145000
# Processing event n.  146000
# Processing event n.  147000
# Processing event n.  148000
# Processing event n.  149000
# Processing event n.  150000
# Processing event n.  151000
# Processing event n.  152000
# Processing event n.  153000
# Processing event n.  154000
# Processing event n.  155000
# Processing event n.  156000
# Processing event n.  157000
# Processing event n.  158000
# Processing event n.  159000
# Processing event n.  160000
# Processing event n.  161000
# Processing event n.  162000
# Processing event n.  163000
# Processing event n.  164000
# Processing event n.  165000
# Processing event n.  166000
# Processing event n.  167000
# Processing event n.  168000
# Processing event n.  169000
# Processing event n.  170000
# Processing event n.  171000
# Processing event n.  172000
# Processing event n.  173000
# Processing event n.  174000
# Processing event n.  175000
# Processing event n.  176000
# Processing event n.  177000
# Processing event n.  178000
# Processing event n.  179000
# Processing event n.  180000
# Processing event n.  181000
# Processing event n.  182000
# Processing event n.  183000
# Processing event n.  184000
# Processing event n.  185000
# Processing event n.  186000
# Processing event n.  187000
# Processing event n.  188000
# Processing event n.  189000
# Processing event n.  190000
# Processing event n.  191000
# Processing event n.  192000
# Processing event n.  193000
# Processing event n.  194000
# Processing event n.  195000
# Processing event n.  196000
# Processing event n.  197000
# Processing event n.  198000
# Processing event n.  199000
# Processing event n.  200000
# Processing event n.  201000
# Processing event n.  202000
# Processing event n.  203000
# Processing event n.  204000
# Processing event n.  205000
# Processing event n.  206000
# Processing event n.  207000
# Processing event n.  208000
# Processing event n.  209000
# Processing event n.  210000
# Processing event n.  211000
# Processing event n.  212000
# Processing event n.  213000
# Processing event n.  214000
# Processing event n.  215000
# Processing event n.  216000
# Processing event n.  217000
# Processing event n.  218000
# Processing event n.  219000
# Processing event n.  220000
# Processing event n.  221000
# Processing event n.  222000
# Processing event n.  223000
# Processing event n.  224000
# Processing event n.  225000
# Processing event n.  226000
# Processing event n.  227000
# Processing event n.  228000
# Processing event n.  229000
# Processing event n.  230000
# Processing event n.  231000
# Processing event n.  232000
# Processing event n.  233000
# Processing event n.  234000
# Processing event n.  235000
# Processing event n.  236000
# Processing event n.  237000
# Processing event n.  238000
# Processing event n.  239000
# Processing event n.  240000
# Processing event n.  241000
# Processing event n.  242000
# Processing event n.  243000
# Processing event n.  244000
# Processing event n.  245000
# Processing event n.  246000
# Processing event n.  247000
# Processing event n.  248000
# Processing event n.  249000
# Processing event n.  250000
# Processing event n.  251000
# Processing event n.  252000
# Processing event n.  253000
# Processing event n.  254000
# Processing event n.  255000
# Processing event n.  256000
# Processing event n.  257000
# Processing event n.  258000
# Processing event n.  259000
# Processing event n.  260000
# Processing event n.  261000
# Processing event n.  262000
# Processing event n.  263000
# Processing event n.  264000
# Processing event n.  265000
# Processing event n.  266000
# Processing event n.  267000
# Processing event n.  268000
# Processing event n.  269000
# Processing event n.  270000
# Processing event n.  271000
# Processing event n.  272000
# Processing event n.  273000
# Processing event n.  274000
# Processing event n.  275000
# Processing event n.  276000
# Processing event n.  277000
# Processing event n.  278000
# Processing event n.  279000
# Processing event n.  280000
# Processing event n.  281000
# Processing event n.  282000
# Processing event n.  283000
# Processing event n.  284000
# Processing event n.  285000
# Processing event n.  286000
# Processing event n.  287000
# Processing event n.  288000
# Processing event n.  289000
# Processing event n.  290000
# Processing event n.  291000
# Processing event n.  292000
# Processing event n.  293000
# Processing event n.  294000
# Processing event n.  295000
# Processing event n.  296000
# Processing event n.  297000
# Processing event n.  298000
# Processing event n.  299000
# Processing event n.  300000
# Processing event n.  301000
# Processing event n.  302000
# Processing event n.  303000
# Processing event n.  304000
# Processing event n.  305000
# Processing event n.  306000
# Processing event n.  307000
# Processing event n.  308000
# Processing event n.  309000
# Processing event n.  310000
# Processing event n.  311000
# Processing event n.  312000
# Processing event n.  313000
# Processing event n.  314000
# Processing event n.  315000
# Processing event n.  316000
# Processing event n.  317000
# Processing event n.  318000
# Processing event n.  319000
# Processing event n.  320000
# Processing event n.  321000
# Processing event n.  322000
# Processing event n.  323000
# Processing event n.  324000
# Processing event n.  325000
# Processing event n.  326000
# Processing event n.  327000
# Processes a total of 354315 clusters
# Final array contains 354315 entries
# stored the final array also as class variable ak_array_unrolled
# length of the vectorized array: 327740
# length of the unrolled array: 354315

# %%
print(dataset_signal.ak_array_raw)
print(dataset_signal.ak_array_unrolled)
print(dataset_signal.np_array_structured)
print(dataset_signal.np_array_unstructured)
# Out:
# [{weight: 23.2, evtNum: 502813, cscRechitCluster_match_gLLP: [True], ...}, ...]
# [{weight: 23.2, evtNum: 502813, cscRechitCluster_match_gLLP: True, ...}, ...]
# None
# None

# %%
print("length of the vectorized array:", len(vectorized_array))
print("length of the unrolled array:", len(unrolled_array))

#print(vectorized_array[0])
#print(unrolled_array[0])
#print(ak.to_numpy(vectorized_array))
#print(ak.to_numpy(unrolled_array))
# Out:
# length of the vectorized array: 327740
# length of the unrolled array: 354315

# %%
# Convert to structured numpy array
numpy_array = dataset_signal.convert_ak_to_numpy(unrolled_array)


# Save structured numpy array to disk 
# Here is use a data directory in my beegfs
# You will need to change the directory of course!
# It is probably a good idea not to store the data in the git directory!
# In the end we only want to do the conversion once and then store signal and QCD somewhere we both can access it
#dataset_signal.save("/beegfs/desy/user/kelmorab/LLP_data/version1_16may2023/signal_structured.h5", mode="structured")
# Out:
# Converted the ak_array.
# Also stored it in self.np_array_structured

# %%
#print(numpy_array)
#print(vectorized_array)
#print(unrolled_array)

# %%
#print(cols)
print(len(cols))
#print(ak.num(ak_array,axis=0))
#print(vectorized_array[0].fields)
#print(vectorized_array[0].values)
df = ak.to_dataframe(unrolled_array)
print(df)
#df = pd.DataFrame(numpy_array,columns=cols)
# Out:
# 772
#            weight  evtNum  cscRechitCluster_match_gLLP  \
# entry
# 0       23.164499  502813                         True
# 1       23.164499  502816                         True
# 2       23.164499  502825                         True
# 3       23.164499  502832                         True
# 4       23.164499  502865                         True
# ...           ...     ...                          ...
# 354310  23.164499  552973                         True
# 354311  23.164499  552984                         True
# 354312  23.164499  552985                         True
# 354313  23.164499  552988                         True
# 354314  23.164499  552996                         True
#
#         cscRechitCluster_match_gLLP_minDeltaR  \
# entry
# 0                                    0.125424
# 1                                    0.064673
# 2                                    0.045700
# 3                                    0.109238
# 4                                    0.148448
# ...                                       ...
# 354310                               0.075991
# 354311                               0.068142
# 354312                               0.090674
# 354313                               0.050335
# 354314                               0.040268
#
#         cscRechitCluster_match_gLLP_index  cscRechitCluster_match_gLLP_eta  \
# entry
# 0                                       1                         2.455880
# 1                                       1                        -2.291653
# 2                                       0                        -1.383178
# 3                                       1                         1.595475
# 4                                       1                        -1.223500
# ...                                   ...                              ...
# 354310                                  1                         1.890387
# 354311                                  0                         1.451552
# 354312                                  0                         1.428784
# 354313                                  1                        -2.136089
# 354314                                  1                        -1.813329
#
#         cscRechitCluster_match_gLLP_phi  cscRechitCluster_match_gLLP_decay_r  \
# entry
# 0                              0.013887                           135.929657
# 1                             -1.161893                           180.937042
# 2                              0.424101                           262.461548
# 3                              0.749391                           323.136871
# 4                             -1.734045                           271.693176
# ...                                 ...                                  ...
# 354310                         1.731617                           187.341919
# 354311                         0.831516                           427.336212
# 354312                        -1.782127                           320.700378
# 354313                        -1.151250                           136.881149
# 354314                        -1.136297                           177.611969
#
#         cscRechitCluster_match_gLLP_decay_z  cscRechitCluster_match_gLLP_csc  \
# entry
# 0                                791.838928                            False
# 1                               -883.040771                             True
# 2                               -497.735138                             True
# 3                                769.962891                             True
# 4                               -423.666504                             True
# ...                                     ...                              ...
# 354310                           605.115845                             True
# 354311                           861.995789                             True
# 354312                           630.612793                             True
# 354313                          -569.946716                             True
# 354314                          -530.892944                             True
#
#         ...  cscRechitClusterNRechitChamberMinus11  \
# entry   ...
# 0       ...                                      0
# 1       ...                                      0
# 2       ...                                      0
# 3       ...                                      0
# 4       ...                                      0
# ...     ...                                    ...
# 354310  ...                                      0
# 354311  ...                                      0
# 354312  ...                                      0
# 354313  ...                                    219
# 354314  ...                                    880
#
#         cscRechitClusterNRechitChamberMinus12  \
# entry
# 0                                           0
# 1                                           0
# 2                                        1251
# 3                                           0
# 4                                          83
# ...                                       ...
# 354310                                      0
# 354311                                      0
# 354312                                      0
# 354313                                      0
# 354314                                      8
#
#         cscRechitClusterNRechitChamberMinus13  \
# entry
# 0                                           0
# 1                                           0
# 2                                           0
# 3                                           0
# 4                                           0
# ...                                       ...
# 354310                                      0
# 354311                                      0
# 354312                                      0
# 354313                                      0
# 354314                                      0
#
#         cscRechitClusterNRechitChamberMinus21  \
# entry
# 0                                           0
# 1                                           0
# 2                                           0
# 3                                           0
# 4                                           0
# ...                                       ...
# 354310                                      0
# 354311                                      0
# 354312                                      0
# 354313                                      0
# 354314                                     49
#
#         cscRechitClusterNRechitChamberMinus22  \
# entry
# 0                                           0
# 1                                           0
# 2                                          86
# 3                                           0
# 4                                          12
# ...                                       ...
# 354310                                      0
# 354311                                      0
# 354312                                      0
# 354313                                      0
# 354314                                      0
#
#         cscRechitClusterNRechitChamberMinus31  \
# entry
# 0                                           0
# 1                                         784
# 2                                           0
# 3                                           0
# 4                                           0
# ...                                       ...
# 354310                                      0
# 354311                                      0
# 354312                                      0
# 354313                                      0
# 354314                                     12
#
#         cscRechitClusterNRechitChamberMinus32  \
# entry
# 0                                           0
# 1                                           0
# 2                                          43
# 3                                           0
# 4                                           6
# ...                                       ...
# 354310                                      0
# 354311                                      0
# 354312                                      0
# 354313                                      0
# 354314                                      0
#
#         cscRechitClusterNRechitChamberMinus41  \
# entry
# 0                                           0
# 1                                         585
# 2                                           0
# 3                                           0
# 4                                           0
# ...                                       ...
# 354310                                      0
# 354311                                      0
# 354312                                      0
# 354313                                      0
# 354314                                     12
#
#         cscRechitClusterNRechitChamberMinus42  cscRechitClusterMet_dPhi
# entry
# 0                                           0                  2.706374
# 1                                           0                 -2.538717
# 2                                           0                 -0.402935
# 3                                           0                 -0.051572
# 4                                           6                 -2.604522
# ...                                       ...                       ...
# 354310                                      0                 -0.425591
# 354311                                      0                 -1.424646
# 354312                                      0                  2.544108
# 354313                                      0                 -1.112734
# 354314                                      0                 -2.306015
#
# [354315 rows x 79 columns]

# %%
#save the structured numpy array to disk
#dataset_signal.save("/nfs/dust/cms/user/lbenato/ML_LLP/MDS_regression/datasets/test_v6.h5", mode = "structured")

# %%
#save the pandas dataframe
df.to_hdf('/nfs/dust/cms/user/loewetob/ML_LLP/MDS_regression/datasets/test_bigger_dataset.h5', 'df', format='table' if (len(cols)<=2000) else 'fixed')
